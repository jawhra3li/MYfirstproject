# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 30.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os

# %%
import kagglehub

path = kagglehub.dataset_download(
    "pkdarabi/medical-image-dataset-brain-tumor-detection"
)

print(path)
# Out:
# ...
# 100%|██████████| 297M/297M [00:02<00:00, 112MB/s]
# Extracting files...
# /root/.cache/kagglehub/datasets/pkdarabi/medical-image-dataset-brain-tumor-detection/versions/5

# %%
import os

for root, dirs, files in os.walk(path):
    print(root)
    print(files[:5])
# Out:
# /root/.cache/kagglehub/datasets/pkdarabi/medical-image-dataset-brain-tumor-detection/versions/5
# []
# /root/.cache/kagglehub/datasets/pkdarabi/medical-image-dataset-brain-tumor-detection/versions/5/BrainTumor
# []
# /root/.cache/kagglehub/datasets/pkdarabi/medical-image-dataset-brain-tumor-detection/versions/5/BrainTumor/BrainTumorYolov9
# ['data.yaml']
# /root/.cache/kagglehub/datasets/pkdarabi/medical-image-dataset-brain-tumor-detection/versions/5/BrainTumor/BrainTumorYolov9/train
# []
# /root/.cache/kagglehub/datasets/pkdarabi/medical-image-dataset-brain-tumor-detection/versions/5/BrainTumor/BrainTumorYolov9/train/images
# ['1925_jpg.rf.9498d957b51035025e5b5f378ca5e567.jpg', '2931_jpg.rf.cb9e5ddc486de0e1b24b6325c0bd0483.jpg', '1335_jpg.rf.5020d85ebca11a97b8f3b72179589301.jpg', '1669_jpg.rf.d5050d3583e5bff720439f2b0ccf75d8.jpg', '616_jpg.rf.4194583bbc5bbaadafa750ed250ad6bd.jpg']
# ...

# %%
yaml_path = "/root/.cache/kagglehub/datasets/pkdarabi/medical-image-dataset-brain-tumor-detection/versions/5/BrainTumor/BrainTumorYolov11/data.yaml"


print(open(yaml_path).read())
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 3
# names: ['glioma', 'meningioma', 'pituitary']

# %%
from ultralytics import YOLO


model = YOLO("yolo11m.pt")

# %%
dataset_yaml = "/root/.cache/kagglehub/datasets/pkdarabi/medical-image-dataset-brain-tumor-detection/versions/5/BrainTumor/BrainTumorYolov11/data.yaml"

print(dataset_yaml)
# Out:
# /root/.cache/kagglehub/datasets/pkdarabi/medical-image-dataset-brain-tumor-detection/versions/5/BrainTumor/BrainTumorYolov11/data.yaml

# %%
import os

print(os.path.exists(dataset_yaml))
# Out:
# True

# %%
from ultralytics import YOLO

model = YOLO("yolo11m.pt")

# %%
results = model.train(
    data=dataset_yaml,
    epochs=100,
    imgsz=640,
    batch=16,
    optimizer="AdamW",
    patience=15,
    device=0
)
# Out:
# Ultralytics 8.4.102 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO(
    "runs/detect/train/weights/best.pt"
)

# %%
test_image = "/root/.cache/kagglehub/datasets/pkdarabi/medical-image-dataset-brain-tumor-detection/versions/5/BrainTumor/BrainTumorYolov11/test/images/1122_jpg.rf.e5b7d9dd059312db750f9a9574ab9cf2.jpg"

# %%
import os

print(os.path.exists(test_image))
# Out:
# True

# %%
results = model.predict(
    source=test_image,
    conf=0.4,
    save=True
)
# Out:
# image 1/1 /root/.cache/kagglehub/datasets/pkdarabi/medical-image-dataset-brain-tumor-detection/versions/5/BrainTumor/BrainTumorYolov11/test/images/1122_jpg.rf.e5b7d9dd059312db750f9a9574ab9cf2.jpg: 640x640 (no detections), 7.2ms
# Speed: 2.3ms preprocess, 7.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict

# %%
results = model.predict(
    source=test_image,
    conf=0.1,
    save=True
)
# Out:
# image 1/1 /root/.cache/kagglehub/datasets/pkdarabi/medical-image-dataset-brain-tumor-detection/versions/5/BrainTumor/BrainTumorYolov11/test/images/1122_jpg.rf.e5b7d9dd059312db750f9a9574ab9cf2.jpg: 640x640 1 negative, 40.4ms
# Speed: 8.1ms preprocess, 40.4ms inference, 13.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict

# %%
print(model.names)
# Out:
# {0: 'negative', 1: 'positive'}

# %%
print(model.ckpt['train_args']['data'])
# Out:
# /usr/local/lib/python3.12/dist-packages/ultralytics/cfg/datasets/brain-tumor.yaml

# %%
dataset_yaml = "/root/.cache/kagglehub/datasets/pkdarabi/medical-image-dataset-brain-tumor-detection/versions/5/BrainTumor/BrainTumorYolov11/data.yaml"

print(open(dataset_yaml).read())
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 3
# names: ['glioma', 'meningioma', 'pituitary']

# %%
dataset_yaml = "/root/.cache/kagglehub/datasets/pkdarabi/medical-image-dataset-brain-tumor-detection/versions/5/BrainTumor/BrainTumorYolov11/data.yaml"

# %%
print(open(dataset_yaml).read())
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 3
# names: ['glioma', 'meningioma', 'pituitary']

# %%
from ultralytics import YOLO

model = YOLO("yolo11m.pt")

results = model.train(
    data=dataset_yaml,
    epochs=50,
    imgsz=640,
    batch=16,
    optimizer="AdamW",
    patience=10,
    name="brain_tumor_3class_50"
)
# Out:
# Ultralytics 8.4.102 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'datasets', 'runs', 'yolo11m.pt', 'yolov8n.pt', 'yolo26n.pt', 'sample_data']

# %%
import os

for root, dirs, files in os.walk("/content/datasets"):
    print(root, len(files))
    if len(files) > 0:
        print(files[:5])
        break
# Out:
# /content/datasets 0
# /content/datasets/brain-tumor 2
# ['brain-tumor.yaml', 'LICENSE.txt']
